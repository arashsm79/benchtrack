# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from benchtrack.benchtrack_import import import_from_horse30
from benchtrack.benchtrack_dj import Project, Subject, Session, Video, VideoInfo, TrackingBenchmark, TrackingBenchmarkSettingsLookup, schema
import datajoint as dj
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2024-11-19 14:10:51,824 [DEBUG] Loaded backend inline version unknown.

# %%
dj.Diagram(schema).draw()
# Out:
# 2024-11-19 14:10:53,684 [DEBUG] pydot initializing
# 2024-11-19 14:10:53,685 [DEBUG] pydot 3.0.2
# 2024-11-19 14:10:53,689 [DEBUG] pydot dot_parser module initializing
# 2024-11-19 14:10:53,692 [DEBUG] pydot core module initializing
# 2024-11-19 14:10:53,858 [DEBUG] STREAM b'IHDR' 16 13
# 2024-11-19 14:10:53,859 [DEBUG] STREAM b'bKGD' 41 6
# 2024-11-19 14:10:53,860 [DEBUG] b'bKGD' 41 6 (unknown)
# 2024-11-19 14:10:53,861 [DEBUG] STREAM b'IDAT' 59 8192

# %% [markdown]
# # Import Horse-30

# %%
import_from_horse30("/home/arash/dev/benchtrack/data/horse10/labeled-data")
# Out:
# Imported TwoHorsesinvideobothmoving.

# %%
session_to_benchmark = Session * (TrackingBenchmarkSettingsLookup & 'setting_id=1')
TrackingBenchmark.populate(session_to_benchmark)
# Out:
# {'success_count': 0, 'error_list': []}

# %%
TrackingBenchmark.render_overlay(session_to_benchmark, 'tracked.mp4')

# %%
TrackingBenchmark.stat_table(session_to_benchmark)
# Out:
#    Subject      Segment Name  Average RMSE  Number of Events
# 0    sub-1             Elbow      1.081184                 2
# 1    sub-1               Eye      0.573394                 0
# 2    sub-1             Girth      1.098560                 1
# 3    sub-1               Hip      0.603344                 0
# 4    sub-1           Ischium      0.686964                 0
# 5    sub-1       Midshoulder      1.153503                 0
# 6    sub-1  Nearfrontfetlock      0.786001                 0
# 7    sub-1     Nearfrontfoot      0.452128                 3
# 8    sub-1   Nearhindfetlock      0.950584                 2
# 9    sub-1      Nearhindfoot      0.658195                 3
# 10   sub-1      Nearhindhock      0.845187                 2
# 11   sub-1          Nearknee      0.805223                 1
# 12   sub-1              Nose      1.124493                 2
# 13   sub-1   Offfrontfetlock      0.771054                 3
# ...

# %%
TrackingBenchmark.plot_keypoint_rmse(session_to_benchmark)
# Out:
# 2024-11-19 11:00:53,707 [DEBUG] findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=16.0.
# 2024-11-19 11:00:53,708 [DEBUG] findfont: score(FontEntry(fname='/media1/data/arash/dev/benchtrack/.venv/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-11-19 11:00:53,710 [DEBUG] findfont: score(FontEntry(fname='/media1/data/arash/dev/benchtrack/.venv/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# ...
